# %%
import pandas as pd
import numpy as np
import os
import pandas as pd
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt

# %%
#The final outbound dataset is uploaded 
outbound = pd.read_csv(r"C:\Users\frifi\OneDrive\Desktop\School Mat UHasselt\Third Semester\Project Data Science\Data sets\Outbound\'Outbound_final_2.csv")
outbound
# Out:
#      Order Date  Nb of pallets  Nb of colli  Workload(hrs)  Tot Nb of pallet  \
# 0    2022-01-01            0.0          2.0           0.16              0.04
# 1    2022-01-03          130.0       1851.0         205.71            167.02
# 2    2022-01-04           54.0       1200.0         116.24             78.00
# 3    2022-01-05           49.0       1362.0         117.78             76.24
# 4    2022-01-06           14.0        941.0          75.50             32.82
# ..          ...            ...          ...            ...               ...
# 485  2022-05-01            0.0          1.0           0.09              0.02
# 486  2022-05-15            4.0          0.0           2.10              4.00
# 487  2022-06-05            0.0         23.0           1.30              0.46
# 488  2023-01-08            4.0          0.0           2.14              4.00
# 489  2023-05-14            1.0          0.0           0.55              1.00
#
# ...

# %%
# Scatter plot showing relationship between Number of Pallets and number of colli 
plt.figure(figsize=(10, 6))

# Scatter plot
sns.scatterplot(x='Nb of colli', y='Nb of pallets', data=outbound, palette='viridis')

# Adding labels and title
plt.xlabel('Number of colli')
plt.ylabel('Number of colli')
plt.title('Scatter Plot of Pallets vs. Colli')

# Display the plot
plt.show()
# Out:
# C:\Users\frifi\AppData\Local\Temp\ipykernel_29188\1590551943.py:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='Nb of colli', y='Nb of pallets', data=outbound, palette='viridis')

# %%
# Scatter plot showing relationship between Number of Pallets and number of Workload 
plt.figure(figsize=(10, 6))

# Scatter plot
sns.scatterplot(x='Nb of pallets', y='Workload(hrs)', data=outbound, palette='viridis')

# Adding labels and title
plt.xlabel('Number of Pallets')
plt.ylabel('Workload(hrs)')
plt.title('Scatter Plot of Pallets vs. Workload')

# Display the plot
plt.show()
# Out:
# C:\Users\frifi\AppData\Local\Temp\ipykernel_29188\2785541766.py:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='Nb of pallets', y='Workload(hrs)', data=outbound, palette='viridis')

# %%
# Scatter plot showing relationship between Number of Colli and number of Workload 
plt.figure(figsize=(10, 6))

# Scatter plot
sns.scatterplot(x='Nb of colli', y='Workload(hrs)', data=outbound, palette='viridis')

# Adding labels and title
plt.xlabel('Number of colli')
plt.ylabel('Workload(hrs)')
plt.title('Scatter Plot of Colli vs. Workload')

# Display the plot
plt.show()
# Out:
# C:\Users\frifi\AppData\Local\Temp\ipykernel_29188\2319549029.py:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='Nb of colli', y='Workload(hrs)', data=outbound, palette='viridis')

# %%
# Plotting a bar plot for the distribution of Order Frequency

plt.figure(figsize=(8, 6))
sns.countplot(x='Order Freq', data=outbound)
plt.title('Distribution of Order Frequency')
plt.show()
